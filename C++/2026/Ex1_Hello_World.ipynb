// %%
#include <iostream>
std::cout << "Hello from C++!" << std::endl;
// Out:
// Hello from C++!

// %%
std::string name;
std::cin >> name;
std::cout<< " Welcome "<< name << " ! " << std::endl;
// Out:
//  ilker
//  Welcome ilker !
